# %%
import pandas as pd

df = pd.read_excel("filtered_table_data.xlsx")
df.head()
# Out:
#          Fish             Location        Time              Season Weather  \
# 0  Pufferfish                Ocean  12pm – 4pm              Summer     Sun
# 1     Anchovy                Ocean     Anytime         Spring Fall     Any
# 2        Tuna                Ocean   6am – 7pm       Summer Winter     Any
# 3     Sardine                Ocean   6am – 7pm  Spring Fall Winter     Any
# 4       Bream  River (Town+Forest)   6pm – 2am         All Seasons     Any
#
#   Start Time End Time Actual Start Time Actual End Time
# 0      12pm       4pm             12pm              4pm
# 1    Anytime      NaN              6am              2am
# 2       6am       7pm              6am              7pm
# 3       6am       7pm              6am              7pm
# 4       6pm       2am              6pm              2am

# %%
# Define valid season names
valid_seasons = {"Spring", "Fall", "Summer", "Winter", "All Seasons"}

# Function to correctly split the Season column
def split_seasons(season):
    # Ensure "All Seasons" remains intact
    if season == "All Seasons":
        return [season]  # Return as a single-element list
    return season.split()  # Split all others

# Apply the function and explode
df["Season"] = df["Season"].apply(split_seasons)
df_exploded = df.explode("Season").reset_index(drop=True)

# Filter to keep only valid seasons
df_filtered = df_exploded[df_exploded["Season"].isin(valid_seasons)].reset_index(drop=True)

# Replace "All Seasons" with ["Spring", "Summer", "Fall", "Winter"]
df_filtered["Season"] = df_filtered["Season"].apply(lambda x: ["Spring", "Summer", "Fall", "Winter"] if x == "All Seasons" else [x])

# Explode again to ensure each season gets its own row
df_final = df_filtered.explode("Season").reset_index(drop=True)

# %%
# Define valid weather options
valid_weather = {"Sun", "Wind", "Rain", "Any"}

# Function to correctly split the Weather column
def split_weather(weather):
    # If weather is "any", replace it with all three options
    if weather == "Any":
        return ["Sun", "Wind", "Rain"]
    return weather.split()  # Split combined weather values

# Apply function to the Weather column in df_final
df_final["Weather"] = df_final["Weather"].apply(split_weather)

# Explode the Weather column to separate rows
df_exploded_weather = df_final.explode("Weather").reset_index(drop=True)

# Filter only valid weather values
df_filtered_weather = df_exploded_weather[df_exploded_weather["Weather"].isin(valid_weather)].reset_index(drop=True)

# %%
df_exploded_weather.to_excel("filtered_table_data_transformed.xlsx")
